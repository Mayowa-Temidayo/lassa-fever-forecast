# %% [markdown]
# # AI-Driven Forecasting of Lassa Fever Outbreaks in Nigeria
#
# ## End-to-End Machine Learning Pipeline
#
# Author:
#
# Date:
#
# ---

# %% [markdown]
# # Phase 2
#
# ## Data Acquisition
#
# The objective of this phase is to construct a reproducible data ingestion pipeline for epidemiological, environmental, demographic, and geographic datasets required for forecasting Lassa fever outbreaks in Nigeria.
#
# No preprocessing or feature engineering is performed during this phase.

# %% [markdown]
# # Phase 2.2
#
# ## Epidemiological Data Acquisition
#
# This section ingests the original surveillance dataset exactly as provided.
#
# No feature engineering or column renaming is performed.
#
# The objective is to preserve source fidelity while validating structural integrity.

# %%
from lassa_fever_forecast.data.fetch_epidemiology import (
    fetch,
)

print("Project initialized.")
# Out:
# Project initialized.

# %%
dataset = fetch()

print(dataset)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 dataset = fetch()
#       2
#       3 print(dataset)
#
# File C:\Engineering\02_Projects\lassa-fever-forecast\src\lassa_fever_forecast\data\fetch_epidemiology.py:29, in fetch()
#      26 dataset_path = get_dataset_path()
#      28 if not dataset_path.exists():
# ---> 29     raise FileNotFoundError(f"Dataset not found:\n{dataset_path}")
#      31 return dataset_path
#
# FileNotFoundError: Dataset not found:
# C:\Engineering\02_Projects\lassa-fever-forecast\data\raw\epidemiology\lassa_surveillance.csv

# %%
import sys

print(sys.executable)
# Out:
# c:\Engineering\02_Projects\lassa-fever-forecast\.venv\Scripts\python.exe
