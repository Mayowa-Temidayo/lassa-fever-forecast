# %% [markdown]
# # AI-Driven Forecasting of Lassa Fever Outbreaks in Nigeria
#
# ## End-to-End Machine Learning Pipeline
#
# Author:
#
# Date:
#
# ---

# %% [markdown]
# # Phase 2.2
#
# ## Epidemiological Data Acquisition
#
# This section ingests the original surveillance dataset exactly as provided.
#
# No feature engineering or column renaming is performed.
#
# The objective is to preserve source fidelity while validating structural integrity.

# %%
import pandas as pd

from lassa_fever_forecast.data.fetch_epidemiology import fetch
from lassa_fever_forecast.data.loaders import load_csv
from lassa_fever_forecast.data.profiler import profile_dataset

pd.set_option("display.max_columns", None)
pd.set_option("display.width", 120)

# %%
dataset_path = fetch()

print(dataset_path)
# Out:
# C:\Engineering\02_Projects\lassa-fever-forecast\data\raw\epidemiology\lassa_fever_timeseries_full.csv

# %%
df = load_csv(dataset_path)

df.head()

# %%
df["week_start_date"] = pd.to_datetime(df["week_start_date"])
df["week_end_date"] = pd.to_datetime(df["week_end_date"])

df.dtypes

# %%
print(f"Rows: {df.shape[0]:,}")
print(f"Columns: {df.shape[1]}")
# Out:
# Rows: 313
# Columns: 11

# %%
profile = profile_dataset(df)

profile
# Out:
# {'rows': 313,
#  'columns': 11,
#  'column_names': ['week_start_date',
#   'week_end_date',
#   'epi_year',
#   'epi_week',
#   'suspected_cases',
#   'confirmed_cases',
#   'probable_cases',
#   'deaths',
#   'extraction_method',
#   'extraction_timestamp',
#   'report_pdf_url'],
#  'dtypes': {'week_start_date': 'object',
#   'week_end_date': 'object',
#   'epi_year': 'int64',
#   'epi_week': 'int64',
#   'suspected_cases': 'int64',
#   'confirmed_cases': 'int64',
#   'probable_cases': 'int64',
#   'deaths': 'int64',
#   'extraction_method': 'object',
#   'extraction_timestamp': 'object',
#   'report_pdf_url': 'object'},
#  'missing_values': {'week_start_date': 0,
#   'week_end_date': 0,
#   'epi_year': 0,
#   'epi_week': 0,
#   'suspected_cases': 0,
#   'confirmed_cases': 0,
#   'probable_cases': 0,
#   'deaths': 0,
#   'extraction_method': 0,
#   'extraction_timestamp': 0,
#   'report_pdf_url': 0},
#  'duplicate_rows': 0,
#  'memory_mb': np.float64(0.13)}

# %%
df.dtypes
# Out:
# week_start_date         object
# week_end_date           object
# epi_year                 int64
# epi_week                 int64
# suspected_cases          int64
# confirmed_cases          int64
# probable_cases           int64
# deaths                   int64
# extraction_method       object
# extraction_timestamp    object
# report_pdf_url          object
# dtype: object

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# week_start_date         0
# week_end_date           0
# epi_year                0
# epi_week                0
# suspected_cases         0
# confirmed_cases         0
# probable_cases          0
# deaths                  0
# extraction_method       0
# extraction_timestamp    0
# report_pdf_url          0
# dtype: int64

# %%
df.describe(include="all").T
# Out:
#                       count unique                                                top freq         mean         std  \
# week_start_date         313    313                                         2019-12-30    1          NaN         NaN
# week_end_date           313    313                                         2020-01-05    1          NaN         NaN
# epi_year              313.0    NaN                                                NaN  NaN  2022.492013    1.713661
# epi_week              313.0    NaN                                                NaN  NaN    26.584665   15.082891
# suspected_cases       313.0    NaN                                                NaN  NaN   152.760383  111.765939
# confirmed_cases       313.0    NaN                                                NaN  NaN    20.626198   25.664706
# probable_cases        313.0    NaN                                                NaN  NaN     0.169329    0.588418
# deaths                313.0    NaN                                                NaN  NaN     3.220447    4.552327
# extraction_method       313      3                                          automated  251          NaN         NaN
# extraction_timestamp    313    264                                   2025-12-01T02:00   35          NaN         NaN
# report_pdf_url          313    311  https://ncdc.gov.ng/themes/common/files/sitrep...    2          NaN         NaN
#
#                          min     25%     50%     75%     max
# week_start_date          NaN     NaN     NaN     NaN     NaN
# week_end_date            NaN     NaN     NaN     NaN     NaN
# epi_year              2020.0  2021.0  2022.0  2024.0  2025.0
# epi_week                 1.0    14.0    27.0    40.0    53.0
# suspected_cases         11.0    81.0   115.0   180.0   694.0
# confirmed_cases          0.0     6.0    10.0    22.0   137.0
# probable_cases           0.0     0.0     0.0     0.0     3.0
# deaths                   0.0     0.0     1.0     4.0    23.0
# extraction_method        NaN     NaN     NaN     NaN     NaN
# extraction_timestamp     NaN     NaN     NaN     NaN     NaN
# report_pdf_url           NaN     NaN     NaN     NaN     NaN

# %%
df.sample(10, random_state=42)
# Out:
#     week_start_date week_end_date  epi_year  epi_week  suspected_cases  confirmed_cases  probable_cases  deaths  \
# 46       2020-11-16    2020-11-22      2020        47               81               10               0       2
# 9        2020-03-02    2020-03-08      2020        10              364               81               2       9
# 206      2023-12-11    2023-12-17      2023        50               93               10               1       4
# 139      2022-08-29    2022-09-04      2022        35               76               10               0       1
# 60       2021-02-22    2021-02-28      2021         8              140               34               0       6
# 33       2020-08-17    2020-08-23      2020        34               47               11               0       3
# 297      2025-09-08    2025-09-14      2025        37              146               11               0       2
# 186      2023-07-24    2023-07-30      2023        30              117               12               0       6
# 296      2025-09-01    2025-09-07      2025        36              147               13               0       2
# 277      2025-04-21    2025-04-27      2025        17              160               11               0       3
#
#     extraction_method        extraction_timestamp                                     report_pdf_url
# 46          automated  2025-12-01T01:09:10.515067  https://ncdc.gov.ng/themes/common/files/sitrep...
# 9           automated  2025-12-01T01:08:45.667156  https://ncdc.gov.ng/themes/common/files/sitrep...
# 206         automated  2025-12-01T01:11:44.451392  https://ncdc.gov.ng/themes/common/files/sitrep...
# 139            manual            2025-12-01T02:00  https://ncdc.gov.ng/themes/common/files/sitrep...
# 60          automated  2025-12-01T01:09:17.323422  https://ncdc.gov.ng/themes/common/files/sitrep...
# 33          automated  2025-12-01T01:09:00.099579  https://ncdc.gov.ng/themes/common/files/sitrep...
# 297         automated  2025-12-01T01:12:53.252734  https://ncdc.gov.ng/themes/common/files/sitrep...
# 186             mixed  2025-12-01T01:11:28.052668  https://ncdc.gov.ng/themes/common/files/sitrep...
# 296         automated  2025-12-01T01:12:52.742769  https://ncdc.gov.ng/themes/common/files/sitrep...
# 277         automated  2025-12-01T01:12:42.026728  https://ncdc.gov.ng/themes/common/files/sitrep...

# %%
print(df.columns.tolist())
# Out:
# ['week_start_date', 'week_end_date', 'epi_year', 'epi_week', 'suspected_cases', 'confirmed_cases', 'probable_cases', 'deaths', 'extraction_method', 'extraction_timestamp', 'report_pdf_url']
